# %%
from fuc import common , pyvcf
common.load_dataset('pyvcf')
import matplotlib.pyplot as plt
vcf_file = '/Users/ashikaramesh/Documents/LachanceLab/impute/chr_22/example.vcf'

# %%
vf = pyvcf.VcfFrame.from_file(vcf_file)

# %%
vf.plot_hist_info('#AF')
# Out:
# <AxesSubplot:xlabel='#AF', ylabel='Count'>

# %%
print(vf)
# Out:
# <fuc.api.pyvcf.VcfFrame object at 0x7f9bf1206760>

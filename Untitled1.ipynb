# %%
pip install pyvcf
# Out:
# ...
#   Preparing metadata (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/ashikaramesh/miniconda3/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/1y/wwrznkx94r5cc2z58952bz5w0000gn/T/pip-install-fhcyntbp/pyvcf_a5483256b1a3477fb7359a7a43984edc/setup.py'"'"'; __file__='"'"'/private/var/folders/1y/wwrznkx94r5cc2z58952bz5w0000gn/T/pip-install-fhcyntbp/pyvcf_a5483256b1a3477fb7359a7a43984edc/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /private/var/folders/1y/wwrznkx94r5cc2z58952bz5w0000gn/T/pip-pip-egg-info-hp30x43l
#        cwd: /private/var/folders/1y/wwrznkx94r5cc2z58952bz5w0000gn/T/pip-install-fhcyntbp/pyvcf_a5483256b1a3477fb7359a7a43984edc/
# ...

# %%
pip install fuc
# Out:
# ...
#      |████████████████████████████████| 143 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 2.3 MB 4.6 MB/s
# ...
#      |████████████████████████████████| 3.2 MB 13.7 MB/s
# ...
#      |████████████████████████████████| 4.6 MB 11.2 MB/s
# ...
#      |████████████████████████████████| 9.6 MB 9.0 MB/s
# ...
#      |████████████████████████████████| 685 kB 10.7 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 292 kB 12.5 MB/s
# ...
#      |████████████████████████████████| 983 kB 13.5 MB/s
# ...
#      |████████████████████████████████| 470 kB 12.8 MB/s
#   Preparing metadata (setup.py) ... done
# ...
#      |████████████████████████████████| 1.2 MB 4.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      |████████████████████████████████| 400 kB 3.6 MB/s
#   Installing build dependencies ... done
# ...

# %%
from fuc import common , pyvcf

# %%
common.load_dataset('pyvcf')

# %%
vcf_file = '/Users/ashikaramesh/Documents/LachanceLab/impute/chr_22/chr22.filtered.vcf'

# %%
vcf = pyvcf.VcfFrame.from_file(vcf_file)

# %%
vf.plot_hist_info('#AF')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1y/wwrznkx94r5cc2z58952bz5w0000gn/T/ipykernel_42435/2763721449.py in <module>
# ----> 1 vf.plot_hist_info('#AF')
#
# NameError: name 'vf' is not defined
